# %%
# a변수를 선언 후 숫자 리터럴 10 할당
a = 10

# %%
# a 변수값에 20을 더한 결과를 다시 a에 할당
a = a + 10
print(a)
# Out:
# 20

# %%
# a 변수 삭제 후 a 출력
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # a 변수 삭제 후 a 출력
#       2 del a
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
# none : 예약어 중 하나, 값 자체가 아예 없다는 의미
# 'None' : 문자열 리터럴, 예약어 None과는 전혀 다르다.
a = None
print(a)
# Out:
# None
