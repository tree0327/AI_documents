# %% [markdown]
# # 05. RNN: 컴퓨터에게 '기억력' 심어주기 (시계열) 🧠
#
# > **목표**: 주식 가격이나 문장처럼 **순서(시간)**가 중요한 데이터를 처리하는 방법을 배웁니다.
#
# ## 1. 기존 신경망의 건망증
# 기본 신경망은 어제 배운 내용을 오늘 까먹습니다. (독립적)
# - "나는" -> 처리 -> 끝
# - "밥을" -> 처리 -> 끝
# - 문맥을 이해하지 못합니다.
#
# ## 2. RNN의 핵심: 기억을 넘겨주기 (이어달리기)
# RNN(Recurrent Neural Network)은 **이전 단계의 결과(기억)**를 다음 단계로 넘겨줍니다.
#
# **비유 (끝말잇기)**:
# - 전 사람이 "기차"라고 말한 정보를 기억해야, 내가 "차표"라고 말할 수 있죠?
# - 이 **'넘겨주는 기억'**을 **Hidden State**라고 합니다.

# %%
from tensorflow.keras.layers import SimpleRNN, LSTM, Dense
from tensorflow.keras.models import Sequential

# 3. RNN 모델 만들기
model = Sequential()

# (1) 기억력 세포 (SimpleRNN)
# input_shape=(시간길이, 특성개수)
model.add(SimpleRNN(10, input_shape=(5, 1)))

# (2) 결과 출력
model.add(Dense(1))

model.summary()

# %% [markdown]
# # 4. LSTM: 장기 기억 장치
# 기본 RNN은 기억력이 짧습니다. 문장이 길어지면 앞부분을 까먹어요.
# 그래서 **"중요한 건 적어두고, 쓸데없는 건 잊어버리는"** 똑똑한 세포가 **LSTM**입니다.
# (종합 프로젝트에서 주식 예측할 때 쓴 그 모델입니다!)

# %% [markdown]
# ## 5. ⚔️ 도전! 실습 미션
# **미션: 위 코드에서 `SimpleRNN`을 `LSTM`으로 바꿔보세요.**
# 힌트: `from tensorflow.keras.layers import LSTM`은 이미 되어 있습니다.

# %%
# 여기에 코드를 수정해서 작성해보세요
