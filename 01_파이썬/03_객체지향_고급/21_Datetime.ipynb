# %%
import datetime

# %%
# 현재날짜와 시간을 가져오기
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 11, 18, 17, 44, 51, 799349)

# %%
# 특정 날짜와 시간을 생성
datetime.datetime(2023, 10, 3, 10, 15, 5, 0)
# Out:
# datetime.datetime(2023, 10, 3, 10, 15, 5)

# %%
# 특정 형식으로 날짜와 시간을 출력
print(datetime.datetime.now().strftime("%Y-%m-%d"))
# Out:
# 2025-11-18

# %%
# 현재 시간에서 1일 전의 날짜를 계산
datetime.datetime.now() - datetime.timedelta(days = 1)
# Out:
# datetime.datetime(2025, 11, 17, 17, 49, 50, 98551)

# %%
import pytz

# %%
# 시간대 변환
now = datetime.datetime.now()

# %%
new_timezone = pytz.timezone("America/New_York")

# %%
new_datetime = now.astimezone(new_timezone)

# %%
print(new_datetime)
# Out:
# 2025-11-18 03:51:02.213240-05:00
