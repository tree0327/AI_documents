# %%
# tuple: 시퀀스 자료형 중 하나, 불변(immutable)
# 변수 = (항목1, 항목2, 항목3, ...)
x = (1, 2, 3, 4, 5, 6)

# %%
print(x)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = ()

# %%
print(type(x))
# Out:
# <class 'tuple'>

# %%
print(len(x))
# Out:
# 0

# %%
print(x)
# Out:
# ()

# %%
y = tuple()

# %%
print(y)
# Out:
# ()

# %%
print(type(y))
# Out:
# <class 'tuple'>

# %%
x1 = (1, 2, 3, 4, 5)

# %%
# x1[1] = 3과 같이 수정 불가능
print(x1[:2])
# Out:
# (1, 2)

# %%
x2 = "음", "오", "아", "예"

# %%
print(type(x2))
# Out:
# <class 'tuple'>

# %%
print(x2)
# Out:
# ('음', '오', '아', '예')
