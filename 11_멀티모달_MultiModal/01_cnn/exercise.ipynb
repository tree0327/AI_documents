# %% [markdown]
# ### 01-02. Keras 설치 방법
#
# **설치 명령어**

# %%
# Keras, TensorFlow, Matplotlib 라이브러리 설치
# %pip install keras tensorflow matplotlib
# Out:
# Requirement already satisfied: keras in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (3.13.2)
# Requirement already satisfied: tensorflow in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: matplotlib in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: absl-py in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (2.4.0)
# Requirement already satisfied: numpy in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (2.4.2)
# Requirement already satisfied: rich in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (14.3.2)
# Requirement already satisfied: namex in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from keras) (26.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (82.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/jy/SKN23/multimodal/multi_venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %% [markdown]
# ---
#
# ## 02. DNN 구성 요소
#
# ### 02-01. 레이어 (Layer)
#
# - 신경망의 기본 단위로, 입력 데이터를 변환하여 출력으로 전달한다.
# - **Dense Layer**: 모든 입력 뉴런이 모든 출력 뉴런과 연결된 완전 연결 층이다.
#
# ### 02-02. 활성화 함수 (Activation Function)
#
# - 레이어의 출력을 비선형적으로 변환하여 모델의 표현력을 향상한다.
# - **주요 활성화 함수**
#     - **ReLU**: Rectified Linear Unit, $f(x)=\max (0, x)$
#     - **시그모이드(Sigmoid)** : $f(x)=\frac{1}{1+e^{-x}}$
#     - **tanh**: 하이퍼볼릭 탄젠트 함수
#
# ### 02-03. 손실 함수 (Loss Function)
#
# - **손실 함수**: 모델의 예측 값과 실제 값 사이의 오차를 수치화 한다.
#     - **회귀 문제**: MSE, MAE 등
#     - **분류 문제**: Binary Crossentropy, Categorical Crossentropy 등
#
# ### 02-04. 옵티마이저 (Optimizer)
#
# - **옵티마이저**: 손실 함수를 최소화하여 가중치를 업데이트하는 알고리즘이다.
#     - **SGD**, **Adam**, **RMSprop** 등이 있다.

# %% [markdown]
# ---
#
# ## 03. Keras로 DNN 모델 구현하기
#
# ### 03-01. 데이터 준비
#
# - **예제 데이터셋: MNIST 손글씨 숫자 데이터**
#     - 0부터 9까지의 손글씨 이미지로 구성된 데이터셋이다.
#     - 각 이미지는 28x28 픽셀의 그레이스케일 이미지이다.
# - **데이터 로드 및 전처리**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# MNIST 데이터셋 로드
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 데이터 정규화 (0~1 사이 값으로 변환)
# 28x28 이미지를 784차원 1차원 배열로 펼치고 실수형으로 변환
x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255

# 레이블 원-핫 인코딩 (0~9까지의 숫자를 10개 클래스 벡터로 변환)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %% [markdown]
# ### 03-02. 모델 구성
#
# - **Sequential API를 사용한 모델 정의**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 순차적 모델 생성
model = Sequential()
# 입력층 및 첫 번째 은닉층: 512개 노드, 활성화 함수 ReLU, 입력 크기 784
model.add(Dense(512, activation='relu', input_shape=(784,)))
# 두 번째 은닉층: 256개 노드, 활성화 함수 ReLU
model.add(Dense(256, activation='relu'))
# 출력층: 10개 노드 (클래스 개수), 활성화 함수 Softmax (다중 분류)
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# - **모델 요약 출력**

# %%
# 모델 구조 요약 출력
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 535,818 (2.04 MB)
#  Trainable params: 535,818 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ![Standard DNN model](https://www.researchgate.net/figure/Standard-DNN-model-23_fig3_351335975)
#
# 출처: https://www.researchgate.net/figure/Standard-DNN-model-23_fig3_351335975

# %% [markdown]
# ### 03-03. 모델 컴파일
#
# - **손실 함수와 옵티마이저 설정**
#     - **손실 함수**: `categorical_crossentropy` (다중 클래스 분류에 사용)
#     - **옵티마이저**: `adam` (Adaptive Moment Estimation)

# %%
# 모델 컴파일
# optimizer: 최적화 알고리즘 (Adam)
# loss: 손실 함수 (다중 분류를 위한 범주형 교차 엔트로피)
# metrics: 평가 지표 (정확도)
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 03-04. 모델 학습
#
# - **에포크(Epoch)**: 전체 데이터셋을 학습하는 횟수
# - **배치 크기**: 한 번의 업데이트에 사용되는 샘플 수
# - **검증 분할**: 전체 데이터의 20%를 검증용으로 사용

# %%
# 모델 학습
# x_train, y_train: 학습 데이터와 레이블
# epochs: 전체 데이터셋 반복 횟수 10회
# batch_size: 가중치 업데이트 한 번당 샘플 수 128개
# validation_split: 학습 데이터의 20%를 검증 데이터로 사용
history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9258 - loss: 0.2546 - val_accuracy: 0.9609 - val_loss: 0.1279
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9720 - loss: 0.0919 - val_accuracy: 0.9706 - val_loss: 0.0993
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9818 - loss: 0.0568 - val_accuracy: 0.9706 - val_loss: 0.0956
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9883 - loss: 0.0384 - val_accuracy: 0.9723 - val_loss: 0.0909
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0282 - val_accuracy: 0.9739 - val_loss: 0.0901
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9924 - loss: 0.0235 - val_accuracy: 0.9761 - val_loss: 0.0903
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9947 - loss: 0.0166 - val_accuracy: 0.9763 - val_loss: 0.0913
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9960 - loss: 0.0128 - val_accuracy: 0.9784 - val_loss: 0.0938
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9953 - loss: 0.0137 - val_accuracy: 0.9776 - val_loss: 0.0911
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9940 - loss: 0.0170 - val_accuracy: 0.9775 - val_loss: 0.0954

# %% [markdown]
# ---
#
# ## 04. 모델 평가와 예측
#
# ### 04-01. 모델 평가

# %%
# 테스트 데이터를 사용한 모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test)
print('테스트 손실 값:', test_loss)
print('테스트 정확도:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - accuracy: 0.9794 - loss: 0.0806
# 테스트 손실 값: 0.08062513917684555
# 테스트 정확도: 0.9793999791145325

# %% [markdown]
# ### 04-02. 예측 결과 확인
#
# - **테스트 데이터의 첫 번째 이미지 예측**

# %%
import numpy as np

# 테스트 데이터에 대한 예측 수행
predictions = model.predict(x_test)

# 첫 번째 데이터의 예측값(가장 확률 높은 인덱스)과 실제값 비교
predicted_label = np.argmax(predictions[0])
true_label = np.argmax(y_test[0])

print('예측된 레이블:', predicted_label)
print('실제 레이블:', true_label)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step
# 예측된 레이블: 7
# 실제 레이블: 7

# %% [markdown]
# ### 04-03. 학습 곡선 시각화
#
# - **훈련 손실과 검증 손실 그래프**

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# 그래프 한글 폰트 설정 (필요 시 주석 해제하여 사용)
mpl.rcParams['font.family'] = 'APPLEGothic'
mpl.rcParams['axes.unicode_minus'] = False

# 손실(Loss) 그래프 시각화
plt.plot(history.history['loss'], label='훈련 손실')
plt.plot(history.history['val_loss'], label='검증 손실')
plt.xlabel('에포크')
plt.ylabel('손실')
plt.legend()
plt.show()

# %% [markdown]
# - **훈련 정확도와 검증 정확도 그래프**

# %%
# 정확도(Accuracy) 그래프 시각화
plt.plot(history.history['accuracy'], label='훈련 정확도')
plt.plot(history.history['val_accuracy'], label='검증 정확도')
plt.title('훈련 및 검증 정확도')
plt.xlabel('에포크')
plt.ylabel('정확도')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# ## 05. 모델 개선과 최적화
#
# ### 05-01. 과적합 방지 기법
#
# - **드롭아웃(Dropout) 적용**
#     - 일부 뉴런을 랜덤하게 비활성화하여 모델의 일반화 능력을 향상시킨다.

# %%
from tensorflow.keras.layers import Dropout

# 드롭아웃을 적용한 새로운 모델 정의
model = Sequential()
# 첫 번째 은닉층 후 20% 뉴런 비활성화
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
# 두 번째 은닉층 후 20% 뉴런 비활성화
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
# 출력층
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# ### 05-02. 옵티마이저와 학습률 조정

# %%
from tensorflow.keras.optimizers import SGD

# SGD 옵티마이저 사용 (학습률 0.01, 모멘텀 0.9 적용)
optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 05-03. 조기 종료 (Early Stopping)
#
# - **콜백 함수로 조기 종료 적용**
#     - 검증 손실이 증가하면 학습을 조기 종료하여 과적합을 방지한다.

# %%
from tensorflow.keras.callbacks import EarlyStopping

# 조기 종료 설정: 검증 손실(val_loss)을 모니터링하며 2 에포크 동안 개선이 없으면 중단
early_stopping = EarlyStopping(monitor='val_loss', patience=2)

# 학습 실행 (콜백 추가)
history = model.fit(x_train, y_train,
                    epochs=50,
                    batch_size=128,
                    validation_split=0.2,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8370 - loss: 0.5541 - val_accuracy: 0.9325 - val_loss: 0.2310
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9275 - loss: 0.2486 - val_accuracy: 0.9527 - val_loss: 0.1686
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9439 - loss: 0.1892 - val_accuracy: 0.9583 - val_loss: 0.1431
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9552 - loss: 0.1509 - val_accuracy: 0.9635 - val_loss: 0.1237
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9619 - loss: 0.1290 - val_accuracy: 0.9668 - val_loss: 0.1069
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9667 - loss: 0.1127 - val_accuracy: 0.9691 - val_loss: 0.1000
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9700 - loss: 0.0994 - val_accuracy: 0.9721 - val_loss: 0.0922
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9745 - loss: 0.0864 - val_accuracy: 0.9737 - val_loss: 0.0869
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9768 - loss: 0.0787 - val_accuracy: 0.9753 - val_loss: 0.0821
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9787 - loss: 0.0708 - val_accuracy: 0.9768 - val_loss: 0.0793
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9809 - loss: 0.0653 - val_accuracy: 0.9777 - val_loss: 0.0771
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9818 - loss: 0.0610 - val_accuracy: 0.9772 - val_loss: 0.0751
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9839 - loss: 0.0551 - val_accuracy: 0.9779 - val_loss: 0.0724
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9851 - loss: 0.0501 - val_accuracy: 0.9783 - val_loss: 0.0725
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9857 - loss: 0.0482 - val_accuracy: 0.9779 - val_loss: 0.0705
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9867 - loss: 0.0430 - val_accuracy: 0.9778 - val_loss: 0.0710
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9882 - loss: 0.0403 - val_accuracy: 0.9787 - val_loss: 0.0697
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9893 - loss: 0.0378 - val_accuracy: 0.9794 - val_loss: 0.0680
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9901 - loss: 0.0341 - val_accuracy: 0.9797 - val_loss: 0.0669
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0321 - val_accuracy: 0.9794 - val_loss: 0.0692
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9908 - loss: 0.0304 - val_accuracy: 0.9800 - val_loss: 0.0694
