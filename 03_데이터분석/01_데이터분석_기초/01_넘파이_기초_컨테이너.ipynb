# %% [markdown]
# # 01. Numpy 기초: 파이썬의 수학 천재 친구 🧮
#
# > **목표**: 데이터 분석의 필수 라이브러리인 Numpy의 핵심 개념(Array, 차원, 연산)을 이해합니다.
#
# ## 1. Numpy가 왜 필요할까요?
# 파이썬의 기본 `List`도 훌륭하지만, 데이터가 100만 개가 넘어가면 계산 속도가 느려집니다.
# **Numpy(Numerical Python)**는 C언어로 만들어져서 계산 속도가 엄청나게 빠르고, 수학 연산(행렬, 통계)에 최적화되어 있습니다.
#
# - **List**: 다양한 물건을 담을 수 있는 **'배낭'** (유연하지만 무거움)
# - **Numpy Array**: 같은 규격의 상자만 딱딱 쌓아 올린 **'컨테이너 트럭'** (유연하진 않지만, 엄청 빠르고 효율적임)
#
# ## 2. Array(배열) 만들기
# 리스트를 Numpy의 `array`로 바꾸는 순간, 강력한 수학 기능을 사용할 수 있게 됩니다.

# %%
import numpy as np

# 1. 파이썬 리스트 (배낭)
list_data = [1, 2, 3]
print("List:", list_data * 2)  # 리스트는 곱하기를 하면 반복이 됨 (1,2,3,1,2,3)

# 2. Numpy 배열 (컨테이너)
arr_data = np.array([1, 2, 3])
print("Array:", arr_data * 2)  # 배열은 진짜 수학 곱하기가 됨! (2,4,6)

# %% [markdown]
# > [!TIP]
# > **브로드캐스팅 (Broadcasting)**: Numpy의 가장 큰 장점 중 하나입니다. 크기가 다른 배열끼리 연산할 때, Numpy가 알아서 "모자란 부분을 채워서" 계산해줍니다.
# >
# > 예: `[1, 2, 3] + 10`
# > 원래는 리스트와 숫자를 더할 수 없지만, Numpy는 `10`을 `[10, 10, 10]`으로 복사해서 더해줍니다. -> `[11, 12, 13]`

# %%
# 브로드캐스팅 예제
scores = np.array([50, 60, 70])
bonus = 5

print("점수:", scores)
print("보너스 적용:", scores + bonus) # 각각의 점수에 5점씩 다 더해짐!

# %% [markdown]
# ## 3. 차원(Dimension) 이해하기 - 점, 선, 면
# 데이터의 모양(`shape`)을 아는 것이 딥러닝에서 가장 중요합니다.
#
# - **1차원 (Vector)**: 선. `[1, 2, 3]` -> Shape: `(3,)`
# - **2차원 (Matrix)**: 면(엑셀 시트). `[[1, 2], [3, 4]]` -> Shape: `(2, 2)`
# - **3차원 (Tensor)**: 입체(큐브). 이미지 데이터 등이 보통 3차원 이상입니다.

# %%
# 2차원 배열 만들기 (2행 3열)
matrix = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

print("모양(Shape):", matrix.shape)
print("차원(Dim):", matrix.ndim)
print("총 개수(Size):", matrix.size)

# %% [markdown]
# ## 4. 핵심 요약 (Quiz)
#
# **Q1. 파이썬 리스트와 다르게, Numpy 배열에 숫자를 곱하면 어떻게 되나요?**
# 1. 리스트처럼 계속 이어 붙여진다.
# 2. 각 원소마다 숫자가 곱해진다. (수학 연산)
# 3. 에러가 난다.
#
# **Q2. Numpy가 크기가 서로 다른 배열끼리 연산을 할 수 있도록, 모양을 자동으로 맞춰주는 기능은?**
# 1. 스트리밍(Streaming)
# 2. 브로드캐스팅(Broadcasting)
# 3. 캐스팅(Casting)

# %%
# 정답 확인
print("Q1 정답: 2번 (수학 연산이 가능합니다)")
print("Q2 정답: 2번 브로드캐스팅 (자동으로 전파된다는 뜻)")

# %% [markdown]
# ## 5. ⚔️ 도전! 실습 미션
# **미션: `[10, 20, 30]`이라는 배열을 만들고, 모든 값에 `3`을 곱한 결과를 출력해보세요.**

# %%
# 여기에 코드를 작성하세요
