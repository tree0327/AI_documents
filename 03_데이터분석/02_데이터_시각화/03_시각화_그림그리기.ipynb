# %% [markdown]
# # 03. 데이터 그리기: 시각화 (Visualization) 📊
#
# > **목표**: 숫자로 된 데이터를 눈에 확 들어오는 **그래프**로 만드는 방법을 배웁니다. 데이터 분석의 꽃은 **시각화**입니다.
#
# ## 1. 도구 소개
# 파이썬에는 대표적인 미술 도구가 두 개 있습니다.
#
# 1.  **Matplotlib (맷플롯립)**: **도화지와 연필**. 가장 기본적이고 세밀한 그림을 그릴 수 있지만, 코드가 조금 깁니다.
# 2.  **Seaborn (시본)**: **포토샵/필터**. 맷플롯립을 기반으로 더 예쁘고 통계적인 그래프를 쉽게 그려줍니다.
#
# ## 2. 그래프 그리기 실습
# 가상의 성적 데이터를 만들어서 그려봅시다.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 준비
subjects = ['Math', 'English', 'Science', 'History']
scores = [90, 80, 65, 88]

# 1. Matplotlib (기본 막대 그래프)
plt.figure(figsize=(8, 4))
plt.bar(subjects, scores, color='skyblue')
plt.title('My Exam Scores (Matplotlib)')
plt.show()

# %%
# 2. Seaborn (더 예쁜 그래프)
# Seaborn은 테마를 설정하면 전체적인 스타일이 확 바뀝니다.
sns.set_theme(style="whitegrid")

plt.figure(figsize=(8, 4))
sns.barplot(x=subjects, y=scores, palette="viridis")
plt.title('My Exam Scores (Seaborn)')
plt.show()

# %% [markdown]
# ## 3. 다양한 그래프 종류
#
# 1.  **Line Plot (선 그래프)**: 주식, 기온 변화 등 **시간의 흐름**을 볼 때.
# 2.  **Scatter Plot (산점도)**: 키와 몸무게의 관계처럼 **두 변수의 상관관계**를 볼 때.
# 3.  **Histogram (히스토그램)**: 점수 분포 등 데이터가 **어떻게 퍼져 있는지** 볼 때.
#
# ## 4. 핵심 요약 (Quiz)
#
# **Q1. 파이썬의 가장 기본적인 시각화 라이브러리로, '도화지' 역할을 하는 것은?**
# 1. Numpy
# 2. Matplotlib
# 3. Pandas
#
# **Q2. 두 데이터 간의 상관관계(예: 공부 시간과 성적)를 점으로 찍어서 표현하는 그래프는?**
# 1. 산점도 (Scatter Plot)
# 2. 막대 그래프 (Bar Chart)
# 3. 파이 차트 (Pie Chart)

# %%
# 정답 확인
print("Q1 정답: 2번 Matplotlib")
print("Q2 정답: 1번 산점도 (점이 흩뿌려진 그림)")
