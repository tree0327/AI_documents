# %%
print("Hello World")
# Out:
# Hello World

# %%
# 주석 사용하기
print("Hello World") #print("주석입니다")
# Out:
# Hello World

# %%
print("이것은 주석일까요?")
# Out:
# 이것은 주석일까요?

# %%
x = 1
print(x)
# Out:
# 1

# %%
x = "Hello world"
print(x)
# Out:
# Hello world

# %%
2 + 2 # 덧셈
# Out:
# 4

# %%
4 - 1 # 뺄셈
# Out:
# 3

# %%
3 * 2 # 곱셈
# Out:
# 6

# %%
5 / 2 # 나눗셈
# Out:
# 2.5

# %%
7 // 3 # 몫 구하기
# Out:
# 2

# %%
7 % 3 # 나머지 구하기
# Out:
# 1

# %%
2 ** 7 # 거듭제곰 (2의 7승)
# Out:
# 128

# %%
2 ** (1/2) # 2의 제곱근
# Out:
# 1.4142135623730951

# %%
1.2345e5 # 1.2345 * 10^5
# Out:
# 123450.0

# %%
1234.5e-3 #1234.5 * 10^-3
# Out:
# 1.2345

# %%
0b1111111 # 127
# Out:
# 127

# %%
bin(127) # '0b1111111'
# Out:
# '0b1111111'

# %%
0o21 # 17
# Out:
# 17

# %%
oct(17) # '0o21'
# Out:
# '0o21'

# %%
0x1f # 31 => (1 * 16^0) + (f * 16^0)
# Out:
# 31

# %%
hex(31)
# Out:
# '0x1f'

# %%
# Bool Type의 값은 대/소문자를 정확하게 구분해야함.
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True and True #논리곱
# Out:
# True

# %%
True and False #논리곱
# Out:
# False

# %%
False and False #논리곱
# Out:
# False

# %%
False and True #논리곱
# Out:
# False

# %%
True or True # 논리합
# Out:
# True

# %%
True or False # 논리합
# Out:
# True

# %%
False or True # 논리합
# Out:
# True

# %%
False or False #논리합
# Out:
# False

# %%
not True #논리부정
# Out:
# False

# %%
not False #논리부정
# Out:
# True

# %%
# 비교연산자
2 == 2
# Out:
# True

# %%
3 == 2
# Out:
# False

# %%
3 != 2
# Out:
# True

# %%
3 < 2
# Out:
# False

# %%
3 > 2
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
a = 3.5
b = int(3.5)

b = print(((a-b)*a)//b)
print(b)
# Out:
# 0.0
# None

# %%
1.75//3.5
# Out:
# 0.0
