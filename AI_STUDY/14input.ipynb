# %%
# input()
# 키보드 입력을 받을 때 사용하는 내장함수
print(input("아무 값이나 입력하세요."))
# print("1234")
# Out:
# 아무 값이나 입력하세요. 1234
# 1234

# %%
some_str = input("정수 값을 입력해주세요") #str값이 반환된다.
input_value = int(some_str)
# Out:
# 정수 값을 입력해주세요 10

# %%
print(type(input_value))
# Out:
# <class 'int'>

# %%
# 한 줄로 줄여서 이렇게 작성할 수 있다.
input_value = int(input("정수 값을 입력해주세요"))
# Out:
# 정수 값을 입력해주세요 10

# %%
print(type(input_value))
# Out:
# <class 'int'>
