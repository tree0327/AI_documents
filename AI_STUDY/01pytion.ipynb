# %%
import sys
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 11:23:37) [Clang 14.0.6 ]

# %%
# !ls
# Out:
# 01_pytion.ipynb

# %%
# !pwd
# Out:
# /Users/gimdabin/AI_STUDY
